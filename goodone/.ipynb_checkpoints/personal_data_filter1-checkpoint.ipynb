# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv("../learning/Data/personal_spending_data2.csv") # you cant use use data2 BCZ it has been overrided
df.head()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = groupdf['Date'].dt.to_period('M')

# %%
df['Amount'] = df['Amount'].abs()

# %%
new_df = df.pivot_table(index='Month', columns='Type', values='Amount',aggfunc='sum')
new_df = new_df.fillna(new_df.mean())
mode_means = df.groupby('Month')['Mode'].mean()
new_df['Avg_Mode'] = (mode_means >= 0.5).astype(int)
new_df = new_df.reset_index()

# %%
new_df.describe()
# Out:
# Type       events        food  friend/partner        other     personal  \
# count   17.000000   17.000000       17.000000    17.000000    17.000000
# mean   274.000000  373.466667      692.833333   397.166667   810.869231
# std     49.976244  249.323802      362.725074   362.050310   699.220641
# min    121.000000   60.000000      100.000000     1.000000   160.000000
# 25%    274.000000  196.000000      643.000000   306.000000   340.000000
# 50%    274.000000  353.000000      692.833333   397.166667   585.800000
# 75%    274.000000  415.000000      800.000000   397.166667   810.869231
# max    400.000000  991.000000     1716.000000  1693.000000  2553.000000
#
# Type   pocket money     shopping   stationary   Avg_Mode
# count     17.000000    17.000000    17.000000  17.000000
# mean    2621.846154  1911.000000   353.754545   0.235294
# std     1675.982766   759.597426   543.127528   0.437237
# min       50.000000   110.000000     5.000000   0.000000
# ...

# %%
finaldf = new_df.rename(columns={'pocket money':'monthly_income', 'events':'entertainment', 'Avg_Mode': 'mode', 'friend/partner':'friends'})
finaldf.head()
# Out:
# Type    Month  entertainment   food      friends       other     personal  \
# 0     2024-02          300.0   60.0   790.000000  397.166667   810.869231
# 1     2024-03          275.0  300.0   100.000000  397.166667  2030.000000
# 2     2024-04          274.0  155.0   800.000000  397.166667   393.500000
# 3     2024-05          274.0  415.0  1000.000000  280.000000   180.000000
# 4     2024-06          274.0  191.0   692.833333   60.000000   180.000000
#
# Type  monthly_income  shopping  stationary  mode
# 0        2621.846154    1911.0  353.754545     1
# 1        2621.846154     110.0   10.000000     1
# 2         250.000000    1911.0    5.000000     1
# 3        3000.000000    1614.0   10.000000     0
# 4          50.000000    1911.0  353.754545     0

# %%
finaldf['age'] = 22
finaldf['gender'] = 'Male'
finaldf['major_sub'] = 'Computer Science'
finaldf['spent'] = finaldf['food'] + finaldf['entertainment'] + finaldf['friends'] + finaldf['other'] + finaldf['personal'] + finaldf['shopping'] +finaldf['stationary']

# %%
finaldf.describe()
# Out:
# Type   entertainment        food      friends        other     personal  \
# count      17.000000   17.000000    17.000000    17.000000    17.000000
# mean      274.000000  373.466667   692.833333   397.166667   810.869231
# std        49.976244  249.323802   362.725074   362.050310   699.220641
# min       121.000000   60.000000   100.000000     1.000000   160.000000
# 25%       274.000000  196.000000   643.000000   306.000000   340.000000
# 50%       274.000000  353.000000   692.833333   397.166667   585.800000
# 75%       274.000000  415.000000   800.000000   397.166667   810.869231
# max       400.000000  991.000000  1716.000000  1693.000000  2553.000000
#
# Type   monthly_income     shopping   stationary       mode   age        spent
# count       17.000000    17.000000    17.000000  17.000000  17.0    17.000000
# mean      2621.846154  1911.000000   353.754545   0.235294  22.0  4813.090443
# std       1675.982766   759.597426   543.127528   0.437237   0.0  1409.298354
# ...

# %%
finaldf = finaldf.loc[['age', 'gender', 'major_sub', 'monthly_income', 'stationary', 'food', 'shoping','friends','entertainment', 'personal', 'others', 'mode', 'spent']]

# %%
finaldf.to_csv("abcdef.csv")
